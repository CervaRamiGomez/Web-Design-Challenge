# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
cities_data_path = "Resources/cities-2.csv"


# Read the mouse data and the study results
cities_data_path = pd.read_csv(cities_data_path)

# Display the data table for preview
cities_data_path
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
# name X & Y values
x = cities_data_path['Lat']
y = cities_data_path['Max Temp']

# Create a scatter plot based on new dataframe above with circle markers and listed colors
plt.scatter(x, y)

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Tempurature (F)")
plt.title('City Latitude Vs Max Tempurature 01/05/17')
# Display plot
plt.show()

# %%
# name X & Y values
x = cities_data_path['Lat']
y = cities_data_path['Humidity']

# Create a scatter plot based on new dataframe above with circle markers and listed colors
plt.scatter(x, y)

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title('City Latitude Vs Humidity 01/05/17')
# Display plot
plt.show()

# %%
# name X & Y values
x = cities_data_path['Lat']
y = cities_data_path['Cloudiness']

# Create a scatter plot based on new dataframe above with circle markers and listed colors
plt.scatter(x, y)

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('City Latitude Vs Cloudiness 01/05/17')
# Display plot
plt.show()

# %%
# name X & Y values
x = cities_data_path['Lat']
y = cities_data_path['Wind Speed']

# Create a scatter plot based on new dataframe above with circle markers and listed colors
plt.scatter(x, y)

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title('City Latitude Vs Wind Speed 01/05/17')
# Display plot
plt.show()
